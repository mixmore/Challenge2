# %% [markdown]
# <div style="text-align:left;">
#   <span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">This is a small model that explains the idea that I propose as a solution to the second challenge. I built it from scratch. I did not use any other models in building it. It is simple and uses the minimum. However, it is a good simulator of the solution. It helps to understand how the solution works in a good way.</span>
#   </div>

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h2 style='padding: 20px;
#               color:#B2B223;
#               text-align:center;'>
#        Micromodel to MVP (Minimal Viable Product)
#             </h2>
#     </div>

# %% [markdown]
# <div style="text-align:left;">
# <span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">TABLE OF CONTENTS<br/><br/></span>
# <span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">
# <a href="#data1">1. Introduction</a></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; "><br/><br/></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">
# <a href="#data2">2. Review The Idea</a></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; "><br/><br/></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">
# <a href="#data3">3. Smart Contract Functions</a></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; "><br/><br/></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">
# <a href="#data4">4. Blockchain Functions</a></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; "><br/><br/></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">
# <a href="#data5">5. Main Screen</a></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; "><br/><br/></span><span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">
# <a href="#data6">6. Finally</a></span>  </div>

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:70%;
#             font-family:Verdana;
#             letter-spacing:1px">
#             <div id="data1">
#     <h1 style='padding: 20px;
#               color:#B2B223;
#               text-align:center;'>
#         ⭐Introduction⭐
#             </h1>
#     </div>

# %% [markdown]
# This limited model can be used to store data directly on the second layer of the blockchain.
# Smart contracts can be stored in the first layer of the blockchain.
# Programs stored in smart contracts can also be executed through this model.
# Through this model, smart contracts can be written that store data in the second layer.
# It can also be used to search the first and second layers of the blockchain.
# It provides and helps in understanding how this solution can provide proof of the source of the data.

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:70%;
#             font-family:Verdana;
#             letter-spacing:1px">
#              <div id="data2">
#     <h1 style='padding: 20px;
#               color:#B2B223;
#               text-align:center;'>
#         🔎Review The Idea
#             </h1>
#     </div>

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h3 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#         We will start now
#             </h3>
#     </div>

# %% [markdown]
# <div style="text-align:left;">
#   <span style="font-size:12pt; font-family:'Times New Roman', Times, serif; color:#000000; font-weight:bold; ">Import libraries</span>
#   </div>

# %%
import tkinter as tk
from tkinter import *
from tkinter.ttk import * 
import pandas as pd
import numpy as np 
import hashlib
import datetime as date
import csv
from csv import writer
#from pandastable.core import Table
#from pandastable.data import TableModel

import pandastable
from pandastable import Table
from tkinter import messagebox

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:70%;
#             font-family:Verdana;
#             letter-spacing:1px">
#             <div id="data3">
#     <h1 style='padding: 20px;
#               color:#B2B223;
#               text-align:center;'>
#         Smart Contract Functions
#             </h1>
#     </div>

# %%
def insert_contract():
   
    with open('D:/Blockchain/layer1.csv', 'r') as csv:
        last_index = [[x.strip() for x in line.strip().split(',')] for line in csv.readlines()][-1][0]   
        csv.close()
    

    
    with open('D:/Blockchain/layer1.csv', 'r') as csv1:
        last_hash1 = [[x.strip() for x in line.strip().split(',')] for line in csv1.readlines()][-1][1]   
        csv1.close() 
   
    index1 = int(last_index) + 1
    hash1 = last_hash1
    
    data1 = cText1.get(1.0, "end-1c") 
    data2 = cText2.get(1.0, "end-1c") 

    
    hash_string = str(index1) + str(date.datetime.now()) + str(data1) + str(data2) + str(hash1)
    new_hash= hashlib.sha256(hash_string.encode()).hexdigest()

    list_data=[str(index1),str(new_hash),str(date.datetime.now()),str(data1),str(data2), str(hash1)]

    
    
    
    with open('D:/Blockchain/layer1.csv', 'a', newline='') as f_object:  
        writer_object = writer(f_object)
        writer_object.writerow(list_data)  
        f_object.close()
      

    
def contract_search():
    output1 = cText3.get(1.0, "end-1c") 
    
    with open('D:/Blockchain/layer1.csv') as file_obj:
      
         reader_obj = csv.reader(file_obj)
         for row in reader_obj:
            if row[1] == output1:
                #value = int(row[1])
                value = str(row[4])
                
    #cText4.insert_contract(INSERT, value)
    cText4.delete("1.0","end")
    cText4.insert(END, value)
    #cText4.insert(0, "lol")
    #print(value)

    
def contract_view():
    cpt.show()
    cpt.redraw()
    cpt.importCSV('D:/Blockchain/layer1.csv')
        


def excute():
    code = cText4.get(1.0, "end-1c") 
    #result = eval(code)
    #Print(code)
    exec(code)
    #result = eval(code)
    #result_text.insert(INSERT, str(result))
    #print(code)

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:70%;
#             font-family:Verdana;
#             letter-spacing:1px">
#             <div id="data4">
#     <h1 style='padding: 20px;
#               color:#B2B223;
#               text-align:center;'>
#         Blockchain Functions
#             </h1>
#     </div>

# %%
def helloCallBack():
   msg=messagebox.showinfo( "Hello Python", "Hello World")


def insert_block():
   
    with open('D:/Blockchain/layer2.csv', 'r') as csv:
        last_index = [[x.strip() for x in line.strip().split(',')] for line in csv.readlines()][-1][0]   
        csv.close()
        
    with open('D:/Blockchain/layer2.csv', 'r') as csv1:
        last_hash1 = [[x.strip() for x in line.strip().split(',')] for line in csv1.readlines()][-1][1]   
        csv1.close() 
   
    index1 = int(last_index) + 1
    hash1 = last_hash1
    
    data1 = Text1.get(1.0, "end-1c") 
    data2 = Text2.get(1.0, "end-1c") 
    data3 = Text3.get(1.0, "end-1c") 
    data4 = Text4.get(1.0, "end-1c") 

    hash_string = str(index1) + str(date.datetime.now()) + str(data1) + str(data2) +  str(data3) + str(data4) + "user" + str(hash1)
    new_hash= hashlib.sha256(hash_string.encode()).hexdigest()

    list_data=[str(index1),str(new_hash),str(date.datetime.now()),str(data1),str(data2),str(data3),str(data4),'user', str(hash1)]

    with open('D:/Blockchain/layer2.csv', 'a', newline='') as f_object:  
        writer_object = writer(f_object)
        writer_object.writerow(list_data)  
        f_object.close()
      
        
def block_view():
    pt.show()
    pt.redraw()
    pt.importCSV('D:/Blockchain/layer2.csv')

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:70%;
#             font-family:Verdana;
#             letter-spacing:1px">
#             <div id="data5">
#     <h1 style='padding: 20px;
#               color:#B2B223;
#               text-align:center;'>
#         Main Screen
#             </h1>
#     </div>

# %%
window = Tk() 
#window = tk 
window.title('Micromodel to MVP (Minimal Viable Product)')

window_width = 1250
window_height = 650
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()
center_x = int(screen_width/2 - window_width / 2)
center_y = int(screen_height/2 - window_height / 2)
window.geometry(f'{window_width}x{window_height}+{center_x}+{center_y}')


Label1= Label(window,text = "Insert block").place(x = 5, y = 20) 
Text1 = Text(window, height = 1 , width = 20)
Text1.place(x=180, y=20)
Text2 = Text(window, height = 1 , width = 20)
Text2.place(x=380, y=20)
Text3 = Text(window, height = 1 , width = 20)
Text3.place(x=580, y=20)
Text4 = Text(window, height = 1 , width = 20)
Text4.place(x=780, y=20)        

Button1 = Button(window,text = "Insert block",width = 10 ,command = insert_block).place(x = 80,  y = 16)

Button2 = Button(window,text = "View",width = 10 ,command = block_view).place(x = 1000,  y = 16)

cLabel1= Label(window,text = "Contract name").place(x = 5, y = 265) 
cLabel2= Label(window,text = "Code").place(x = 220, y = 295) 

cLabel3= Label(window,text = "Smart Contracts").place(x = 600, y = 265) 


cText1 = Text(window, height = 1 , width = 20, wrap=NONE)
cText1.place(x=10, y=300)

cText2 = Text(window, height = 18 , width = 35, wrap=NONE)
cText2.place(x=10, y=330)
  
cText3 = Text(window, height = 1 , width = 35, wrap=NONE)
cText3.place(x=950, y=300)

cText4 = Text(window, height = 18 , width = 35, wrap=NONE)
cText4.grid(column=0, row=0)
cText4.place(x=950, y=330)   


cButton1 = Button(window,text = "Insert Contract",width = 15 ,command = insert_contract).place(x = 100,  y = 260)

cButton2 = Button(window,text = "View",width = 15, command = contract_view).place(x = 200,  y = 260)

cButton3 = Button(window,text = "Search",width = 10 ,command = contract_search).place(x = 950,  y = 260)

cButton4 = Button(window,text = "Code Execution",width = 15 ,command = excute).place(x = 1100,  y = 260)


Frame1= Frame(window)
Frame1.place(height=200, width=1200, x=20, y=50)
    
pt = Table(Frame1)
pt.show()
pt.redraw()
pt.importCSV('D:/Blockchain/layer2.csv') 



cFrame1= Frame(window)
cFrame1.place(height=330, width=620, x=310, y=280)
    
cpt = Table(cFrame1)
cpt.show()
cpt.redraw()
cpt.importCSV('D:/Blockchain/layer1.csv') 



window.mainloop()

# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:#9248A5;
#             font-size:70%;
#             font-family:Verdana;
#             letter-spacing:1px">
#             <div id="data6">
#     <h1 style='padding: 20px;
#               color:#B2B223;
#               text-align:center;'>
#         ✉️ Finally
#             </h1>
#     </div>

# %% [markdown]
# <div style="text-align:left;">
#   <span style="font-size:12pt; font-family:'Comic Sans MS', 'Chalkboard SE', 'Comic Neue', sans-serif; color:#000000; font-weight:bold; ">Building a new decentralized programming language will revolutionize the world of Web 3.<br/><br/>Because it will be able to build applications and realize ideas that no one was able to achieve before.<br/><br/>This code is to simplify the idea and nothing more than that; the real code will be different from that.<br/><br/>I built this model from scratch.<br/><br/>I am open to communication and discussion.<br/></span>
#   </div>
